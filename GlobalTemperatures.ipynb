# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    0.024384
# b   -0.114186
# c    0.995102
# d    0.642547
# e    1.008060
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
print(s)
# Out:
# a   -1.134857
# b    0.339241
# c   -1.308432
# d    2.638651
# e    1.240904
# dtype: float64

# %%
print (s[0])
print("\n")
print (s[:3])
# Out:
# -1.13485728899
#
#
# a   -1.134857
# b    0.339241
# c   -1.308432
# dtype: float64

# %%
df = pd.DataFrame(s, columns = ['Coluna1'])
df
# Out:
#     Coluna1
# a -1.134857
# b  0.339241
# c -1.308432
# d  2.638651
# e  1.240904

# %%
df['Coluna1']
# Out:
# a   -1.134857
# b    0.339241
# c   -1.308432
# d    2.638651
# e    1.240904
# Name: Coluna1, dtype: float64

# %%
df['Coluna2'] = df['Coluna1'] * 4
df
# Out:
#     Coluna1    Coluna2
# a -1.134857  -4.539429
# b  0.339241   1.356965
# c -1.308432  -5.233730
# d  2.638651  10.554604
# e  1.240904   4.963617

# %%
df.sort_values(by = 'Coluna2')
# Out:
#     Coluna1    Coluna2
# c -1.308432  -5.233730
# a -1.134857  -4.539429
# b  0.339241   1.356965
# e  1.240904   4.963617
# d  2.638651  10.554604

# %%
df[df['Coluna2'] <= 2]
# Out:
#     Coluna1   Coluna2
# a -1.134857 -4.539429
# b  0.339241  1.356965
# c -1.308432 -5.233730

# %%
df.apply(lambda x: min(x) + max(x))
np.mean(df)
# Out:
# Coluna1    0.355101
# Coluna2    1.420405
# dtype: float64

# %%
table = df.describe()
table
# Out:
#         Coluna1    Coluna2
# count  5.000000   5.000000
# mean   0.355101   1.420405
# std    1.657318   6.629274
# min   -1.308432  -5.233730
# 25%   -1.134857  -4.539429
# 50%    0.339241   1.356965
# 75%    1.240904   4.963617
# max    2.638651  10.554604

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv('c:\WinPython-64bit-3.5.3.1Qt5\GlobalTemperatures.csv')
df.tail(10)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3182  2015-03-01                   6.740                              0.060
# 3183  2015-04-01                   9.313                              0.088
# 3184  2015-05-01                  12.312                              0.081
# 3185  2015-06-01                  14.505                              0.068
# 3186  2015-07-01                  15.051                              0.086
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 3182              12.659                          0.096               0.894
# 3183              15.224                          0.137               3.402
# 3184              18.181                          0.117               6.313
# 3185              20.364                          0.133               8.627
# 3186              20.904                          0.109               9.326
# 3187              20.699                          0.110               9.005
# 3188              18.845                          0.088               7.199
# 3189              16.450                          0.059               5.232
# 3190              12.892                          0.093               2.157
# 3191              10.725                          0.154               0.287
#
#       LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 3182                          0.079                          15.193
# 3183                          0.147                          15.962
# 3184                          0.153                          16.774
# 3185                          0.168                          17.390
# 3186                          0.225                          17.611
# 3187                          0.170                          17.589
# 3188                          0.229                          17.049
# 3189                          0.115                          16.290
# 3190                          0.106                          15.252
# 3191                          0.099                          14.774
#
#       LandAndOceanAverageTemperatureUncertainty
# 3182                                      0.061
# 3183                                      0.061
# 3184                                      0.058
# 3185                                      0.057
# 3186                                      0.058
# 3187                                      0.057
# 3188                                      0.058
# 3189                                      0.062
# 3190                                      0.063
# 3191                                      0.062

# %%
df = df.ix[:,:2]
df.head()
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573

# %%
df.describe()
# Out:
#        LandAverageTemperature
# count             3180.000000
# mean                 8.374731
# std                  4.381310
# min                 -2.080000
# 25%                  4.312000
# 50%                  8.610500
# 75%                 12.548250
# max                 19.021000

# %%
plt.figure(figsize = (15, 5))
plt.scatter(x = df['LandAverageTemperature'].index, y = df['LandAverageTemperature'])
plt.title("Temperatura Média da Terra (1750-2015)")
plt.xlabel("Ano")
plt.ylabel("Temperatura media da Terra")
plt.show()

# %%
print(type(df['dt'][0]))
# Out:
# <class 'str'>

# %%
times = pd.DatetimeIndex(df['dt'])
grouped = df.groupby([times.year]).mean()

# %%
plt.figure(figsize = (15, 5))
plt.plot(grouped['LandAverageTemperature'])
plt.title("Yearly Average Land Temperature 1750-2015")
plt.xlabel("Year")
plt.ylabel("Yearly Average Land Temperature")
plt.show()

# %%
grouped.head()
# Out:
#       LandAverageTemperature
# 1750                8.719364
# 1751                7.976143
# 1752                5.779833
# 1753                8.388083
# 1754                8.469333

# %%
df[times.year == 1752]
# Out:
#             dt  LandAverageTemperature
# 24  1752-01-01                   0.348
# 25  1752-02-01                     NaN
# 26  1752-03-01                   5.806
# 27  1752-04-01                   8.265
# 28  1752-05-01                     NaN
# 29  1752-06-01                     NaN
# 30  1752-07-01                     NaN
# 31  1752-08-01                     NaN
# 32  1752-09-01                     NaN
# 33  1752-10-01                   7.839
# 34  1752-11-01                   7.335
# 35  1752-12-01                   5.086

# %%
df[np.isnan(df['LandAverageTemperature'])]
# Out:
#             dt  LandAverageTemperature
# 10  1750-11-01                     NaN
# 16  1751-05-01                     NaN
# 18  1751-07-01                     NaN
# 21  1751-10-01                     NaN
# 22  1751-11-01                     NaN
# 23  1751-12-01                     NaN
# 25  1752-02-01                     NaN
# 28  1752-05-01                     NaN
# 29  1752-06-01                     NaN
# 30  1752-07-01                     NaN
# 31  1752-08-01                     NaN
# 32  1752-09-01                     NaN

# %%
df['LandAverageTemperature'] = df['LandAverageTemperature'].fillna(method='ffill')

# %%
grouped = df.groupby([times.year]).mean()

plt.figure(figsize = (15, 5))
plt.plot(grouped['LandAverageTemperature'])
plt.show()

# %%
from sklearn.linear_model import LinearRegression as LinReg

# %%
x = grouped.index.values.reshape(-1, 1)
y = grouped['LandAverageTemperature'].values

# %%
reg = LinReg()
reg.fit(x, y)
y_preds = reg.predict(x)
print("Accuracy: " + str(reg.score(x, y)))
# Out:
# Accuracy: 0.376683227531

# %%
plt.figure(figsize = (15, 5))
plt.title("Linear Regression")
plt.scatter(x = x, y = y_preds)
plt.scatter(x = x, y = y, c = "b")

# %%
reg.predict(2050)
# Out:
# array([ 9.14631486])
